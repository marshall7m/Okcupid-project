# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('profiles.csv')

# %%
df.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   35         average       mostly other     often  sometimes
# 2   38            thin           anything  socially        NaN
# 3   23            thin         vegetarian  socially        NaN
# 4   29        athletic                NaN  socially      never
#
#                            education  \
# 0      working on college/university
# 1              working on space camp
# 2     graduated from masters program
# 3      working on college/university
# 4  graduated from college/university
#
#                                               essay0  \
# 0  about me:<br />\n<br />\ni would love to think...
# 1  i am a chef: this is what that means.<br />\n1...
# 2  i'm not ashamed of much, but writing public te...
# 3          i work in a library and go to school. . .
# 4  hey how's it going? currently vague on the pro...
#
# ...

# %%
#remove nans
df.isna().any()
# Out:
# age            False
# body_type       True
# diet            True
# drinks          True
# drugs           True
# education       True
# essay0          True
# essay1          True
# essay2          True
# essay3          True
# essay4          True
# essay5          True
# essay6          True
# essay7          True
# essay8          True
# essay9          True
# ethnicity       True
# height          True
# income         False
# job             True
# last_online    False
# location       False
# offspring       True
# orientation    False
# pets            True
# religion        True
# sex            False
# sign            True
# smokes          True
# speaks          True
# status         False
# dtype: bool

# %%
df.fillna({'age':0,
           'body_type':0,
           'diet':0,
           'drugs':0,
           'education':0,
           'essay1':0,
          'essay2':0,
          'essay3':0,
          'essay4':0,
          'essay5':0,
          'essay6':0,
          'essay7':0,
          'essay8':0,
          'essay9':0,
          'ethnicity':0,
          'height':0,
          'job':0,
          'offspring':0,
          'sign':0,
          'pets':0,
          'religion':0,
          'smokes':0,
           'speaks':0,
           'drinks':0,
          'essay0':0},
          inplace=True)

# %%
df.isna().any()
# Out:
# age            False
# body_type      False
# diet           False
# drinks         False
# drugs          False
# education      False
# essay0         False
# essay1         False
# essay2         False
# essay3         False
# essay4         False
# essay5         False
# essay6         False
# essay7         False
# essay8         False
# essay9         False
# ethnicity      False
# height         False
# income         False
# job            False
# last_online    False
# location       False
# offspring      False
# orientation    False
# pets           False
# religion       False
# sex            False
# sign           False
# smokes         False
# speaks         False
# status         False
# dtype: bool

# %%
drink_map = {"not at all": 0, "rarely": 1, "socially": 2, "often": 3, "very often": 4, "desperately": 5}

df["drinks_num"] = df.drinks.map(drink_map)

# %%
essays = ['essay0', 'essay1', 'essay2', 'essay3', 'essay4', 'essay5', 'essay6', 'essay7', 'essay8', 'essay9']

punctuations = ["!", "?", ",", ".", ":", "'",]
#Need help finding a more effiecient method to clean essays and split words into indiv strings
for essay in essays:
    for punctuation in punctuations:
        df[essay] = df[essay].apply(lambda x: str(x).replace(punctuation, ""))
    df[essay] = df[essay].apply(lambda x: x.lower().split(' '))
    
import timeit

start = timeit.default_timer()


stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# Time:  2.8296999971644254e-05

# %%
print(df['essay0'][0])

# %%
introvert_words = ['shy', 'deep talks', 'small talk', 'introverted', 'stay inside', 'libiary', 'write', 'journal', 'stay in']
possible_intro = []

# %%
#create labels

# %%
#train model

# %%
#find accuracy recall etc.
